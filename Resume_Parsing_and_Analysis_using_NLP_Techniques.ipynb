# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
sns.set_style('darkgrid')  # Set the style of seaborn plots to 'darkgrid'
import warnings
warnings.filterwarnings('ignore')  # Ignore warnings to clean up output
import re  # Regular expression library for data cleaning
from sklearn.preprocessing import LabelEncoder  # For encoding labels
from sklearn.model_selection import train_test_split  # Split data into train and test sets
from sklearn.feature_extraction.text import TfidfVectorizer  # Convert text to weighted TF-IDF features
from scipy.sparse import hstack  # For stacking sparse matrices
from sklearn.multiclass import OneVsRestClassifier  # Handle multiclass classification
from sklearn.neighbors import KNeighborsClassifier  # K-nearest neighbors classifier
from sklearn import metrics  # For assessing model performance

# %%
# Load dataset
df = pd.read_csv('UpdatedResumeDataSet.csv')
df.head()  # Display the first few rows of the dataframe
# Out:
#        Category                                             Resume
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...

# %% [markdown]
# #1. Exploratory Data Analysis (EDA)

# %%
category = df['Category'].value_counts().reset_index() # Count occurrences of each category
category
# Out:
#                      Category  count
# 0              Java Developer     84
# 1                     Testing     70
# 2             DevOps Engineer     55
# 3            Python Developer     48
# 4               Web Designing     45
# 5                          HR     44
# 6                      Hadoop     42
# 7                       Sales     40
# 8                Data Science     40
# 9         Mechanical Engineer     40
# 10              ETL Developer     40
# 11                 Blockchain     40
# 12         Operations Manager     40
# 13                       Arts     36
# 14                   Database     33
# 15         Health and fitness     30
# 16                        PMO     30
# 17     Electrical Engineering     30
# 18           Business Analyst     28
# 19           DotNet Developer     28
# 20         Automation Testing     26
# 21  Network Security Engineer     25
# 22             Civil Engineer     24
# 23              SAP Developer     24
# ...

# %%
print(category.columns)  # Display column names
# Out:
# Index(['Category', 'count'], dtype='object')

# %%
plt.figure(figsize=(12, 8))  # Set the figure size for the plot
sns.barplot(x=category['Category'], y=category['count'], palette='cool')  # Create a barplot
plt.show()  # Display the plot

# %%
plt.figure(figsize=(12, 8))
plt.pie(category['count'], labels=category['Category'], colors=sns.color_palette('cool'), autopct='%.0f%%')  # Create a pie chart
plt.title('Category Distribution')  # Set the title of the pie chart
plt.show()  # Display the pie chart

# %% [markdown]
# #2. Data Pre-processing:
# 1. Data Cleaning
# 2. Data Encoding

# %%
def cleanResume(resumeText):
    resumeText = re.sub('http\S+\s*', ' ', resumeText)  # remove URLs
    resumeText = re.sub('RT|cc', ' ', resumeText)  # remove RT and cc
    resumeText = re.sub('#\S+', '', resumeText)  # remove hashtags
    resumeText = re.sub('@\S+', '  ', resumeText)  # remove mentions
    resumeText = re.sub('[%s]' % re.escape("""!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"""), ' ', resumeText)  # remove punctuations
    resumeText = re.sub(r'[^\x00-\x7f]',r' ', resumeText)
    resumeText = re.sub('\s+', ' ', resumeText)  # remove extra whitespace
    return resumeText

# %%
df['cleaned'] = df['Resume'].apply(lambda x: cleanResume(x))  # Apply the cleaning function to the 'Resume' column
df.head()  # Display the first few rows of the cleaned dataframe
# Out:
#        Category                                             Resume  \
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...
#
#                                              cleaned
# 0  Skills Programming Languages Python pandas num...
# 1  Education Details May 2013 to May 2017 B E UIT...
# 2  Areas of Interest Deep Learning Control System...
# 3  Skills R Python SAP HANA Tableau SAP HANA SQL ...
# 4  Education Details MCA YMCAUST Faridabad Haryan...

# %%
#getting the entire resume text
corpus=" "
for i in range(0,len(df)):
    corpus= corpus+ df["cleaned"][i]

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
import string
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
tokenizer = nltk.tokenize.RegexpTokenizer('\w+')
#Tokenizing the text
tokens = tokenizer.tokenize(corpus)
len(tokens)
# Out:
# 411913

# %%
#now we shall make everything lowercase for uniformity
#to hold the new lower case words
words = []
# Looping through the tokens and make them lower case
for word in tokens:
    words.append(word.lower())
words[0:5]
# Out:
# ['skills', 'programming', 'languages', 'python', 'pandas']

# %%
# Data Encoding
label = LabelEncoder()  # Create a LabelEncoder object
df['new_Category'] = label.fit_transform(df['Category'])  # Encode the 'Category' column
df.head()  # Display the first few rows of the dataframe with encoded categories
# Out:
#        Category                                             Resume  \
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...
#
#                                              cleaned  new_Category
# 0  Skills Programming Languages Python pandas num...             6
# 1  Education Details May 2013 to May 2017 B E UIT...             6
# 2  Areas of Interest Deep Learning Control System...             6
# 3  Skills R Python SAP HANA Tableau SAP HANA SQL ...             6
# 4  Education Details MCA YMCAUST Faridabad Haryan...             6

# %%
plt.hist(df['new_Category'])  # Plot a histogram of the new categories
# Out:
# (array([ 82.,  68.,  97.,  83.,  70., 116., 124.,  95.,  72., 155.]),
#  array([ 0. ,  2.4,  4.8,  7.2,  9.6, 12. , 14.4, 16.8, 19.2, 21.6, 24. ]),
#  <BarContainer object of 10 artists>)

# %%
# Vectorizing the cleaned text
text = df['cleaned'].values  # Extract values from the cleaned column
target = df['new_Category'].values  # Extract target values
word_vectorizer = TfidfVectorizer(sublinear_tf=True, stop_words='english', max_features=1500)  # Create a TF-IDF vectorizer
word_vectorizer.fit(text)  # Fit the vectorizer on the text data
WordFeatures = word_vectorizer.transform(text)  # Transform text data into TF-IDF vectors
WordFeatures.shape  # Display the shape of the feature matrix
# Out:
# (962, 1500)

# %% [markdown]
# # 3: Train Test Data and Modeling

# %%
# Separate train and test data
X_train, X_test, y_train, y_test = train_test_split(WordFeatures, target, random_state=24, test_size=0.2)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((769, 1500), (193, 1500), (769,), (193,))

# %%
# Model Training
model = OneVsRestClassifier(KNeighborsClassifier())
model.fit(X_train, y_train)
# Out:
# OneVsRestClassifier(estimator=KNeighborsClassifier())

# %%
# Prediction
y_pred = model.predict(X_test)

# %%
# Display training and validation accuracy
print(f'---------------------------------\n| Training Accuracy   :- {(model.score(X_train, y_train)*100).round(2)}% |')
print(f'---------------------------------\n| Validation Accuracy :- {(model.score(X_test, y_test)*100).round(2)}% |\n---------------------------------')
# Out:
# ---------------------------------
# | Training Accuracy   :- 98.96% |
# ---------------------------------
# | Validation Accuracy :- 96.89% |
# ---------------------------------

# %%
print(metrics.classification_report(y_test, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00         6
#            3       1.00      1.00      1.00         9
#            4       1.00      1.00      1.00         3
#            5       1.00      1.00      1.00         3
#            6       1.00      1.00      1.00         7
#            7       1.00      1.00      1.00         6
#            8       1.00      1.00      1.00        10
#            9       1.00      1.00      1.00         6
#           10       1.00      1.00      1.00        10
#           11       1.00      1.00      1.00         8
#           12       1.00      1.00      1.00         6
#           13       1.00      1.00      1.00         6
#           14       1.00      1.00      1.00         8
#           15       1.00      1.00      1.00        16
# ...

# %% [markdown]
# #4. To learn the top keywords to analyze.

# %%
#Stop words are generally the most common words in a language.
#English stop words from nltk.
stopwords = nltk.corpus.stopwords.words('english')
words_new = []
#Now we need to remove the stop words from the words variable
#Appending to words_new all words that are in words but not in sw
for word in words:
    if word not in stopwords:
        words_new.append(word)

# %%
words_new[0:5]
# Out:
# ['skills', 'programming', 'languages', 'python', 'pandas']

# %%
  import nltk
  nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
# Perform Lemmatization
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
wn = WordNetLemmatizer()
lem_words=[]
for word in words_new:
    word=wn.lemmatize(word)
    lem_words.append(word)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
lem_words[0:5]
# Out:
# ['skill', 'programming', 'language', 'python', 'panda']

# %%
# Initialize counters for the words that remained the same and those that were changed through lemmatization
same = 0
same=0
diff=0
for i in range(0,1832): # Loop through the first 1832 elements of the word lists
    if(lem_words[i]==words_new[i]):
        same=same+1 # Increment the 'same' counter if the word did not change after lemmatization
    elif(lem_words[i]!=words_new[i]):
        diff=diff+1 # Increment the 'diff' counter if the word changed after lemmatization
# Print the number of words that were and were not changed by lemmatization
print('Number of words Lemmatized=', diff)
print('Number of words not Lemmatized=', same)
# Out:
# Number of words Lemmatized= 294
# Number of words not Lemmatized= 1538

# %%
#The frequency distribution of the words
freq_dist = nltk.FreqDist(lem_words)
#Frequency Distribution Plot
plt.subplots(figsize=(20,12))
freq_dist.plot(30)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
# Now we generate wordcloud
res=' '.join([i for i in lem_words if not i.isdigit()])

# %%
# Set up the figure with a specified size
plt.subplots(figsize=(16,10))
# Create a WordCloud object with specific parameters
wordcloud = WordCloud(
                          background_color='black',
                          max_words=100,
                          width=1400,
                          height=1200
                         ).generate(res)
plt.imshow(wordcloud) # Display the word cloud image
plt.title('Resume Text WordCloud (100 Words)') # Set the title of the plot
plt.axis('off') # Remove the axis labels and ticks
plt.show() # Show the plot

# %%
# Set up the figure with a specified size
plt.subplots(figsize=(16,10))
# Create a WordCloud object with specific parameters
wordcloud = WordCloud(
                          background_color='black',
                          max_words=200,
                          width=1400,
                          height=1200
                         ).generate(res)
plt.imshow(wordcloud) # Display the word cloud image
plt.title('Resume Text WordCloud (200 Words)') # Set the title of the plot
plt.axis('off') # Remove the axis labels and ticks
plt.show() # Show the plot
